# %%
args = ['hello', 'world', ]
print(args[0], args[1])

# %%
# %run hello.py

# %%
# %load hello.py
#!/usr/bin/python

import sys

filename=sys.argv[0]
args = sys.argv[1:]

if len(args) == 0:
  args = ['hello,', 'world!']
elif len(args) == 1:
  args.append('world!')

print(args[0], args[1])

# %%
import numpy as np # we use the numpy lib for dot product and creating numpy arrays

# %%
a = np.random.rand(1000, 1000)

# %%
# %time np.dot(a, a)

# %%
# %timeit np.dot(a, a)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt # we use the matplotlib lib for plotting
data = np.random.randn(10).cumsum()
plt.plot(data)

# %%
# %lsmagic
