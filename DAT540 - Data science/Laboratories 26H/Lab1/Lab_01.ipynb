# %% [markdown]
# # Lab 1: Introduction to Python Basics, Data Structures, Variable Operations, and Working with Functions
#
# ### Question 1: Basic operations

# %%
# What is the last value of a ?
# Try to understand the intermediate values of a

a = 20
a -= 18 
a == 3
a *= 6 
a //= 6
a %= 2

# %% [markdown]
# ### Question 2: How to create a simple function with argument and return ?

# %%
# compute the square of 3 using the function square()

def square(a):
    """Return the square of a"""
    return a ** 2

# %% [markdown]
# ### Question 3: How to use an existing function with argument and return ?

# %%
# 1) Find a way to use the function foo() and to return 'FALSE'
# 2) Find a way to use the function foo() and to return 'TRUE'

def foo(foo_input, foo_default):
    if 0 <= foo_input <= 100:
        return f_input
    else:
        return foo_default

# %% [markdown]
# ### Question 4: How to use a simple function without argument and with return ?

# %%
# compute 2 * 4 using function multiplication()

def multiplication():
    """Return the multiplication of 2 global variables"""
    return a * b

# %% [markdown]
# ### Question 5: How to use a simple function without argument and without return ?

# %%
# compute twice a-b using soustraction()
a = 5
b = 3

def subtraction():
    """Return the difference between 2 global variables"""
    print(a - b)

# %% [markdown]
# ### Question 6: Example of for loop and if condition inside a function

# %%
# mylist = [int1, int2, int3]
# create the list 'mylist' with 3 integers in order to print only one of these integers

def filter(seq):
    for x in seq:
        if 0 <= x <= 100:
            continue
        print(x)

# %% [markdown]
# ### Question 7: Example of a function with logical return

# %%
# 1) Find a value to return True
# 2) Find a value to return False

def check(x):
    return 0 <= x <= 100

# %% [markdown]
# ### Question 8: Example of function to call another function and to change the type of a variable

# %%
# What is the final values of the variables a and b ?
# Try to understand the intermediate changes of these variables
a = 3
b = 4

def changetype(x):
    b = square(x)
    a = multiplication()
    return str(a), str(b)

# %% [markdown]
# ### Question 9: Example of function to use local and global variables

# %%
# 1) Check the result of foo(2) and explain
# 2) Check the result of foo(200) and explain

def foo(foo_input):
    if 0 <= foo_input <= 100:
        return f_input
    return None

# %% [markdown]
# ### Question 11: How to evaluate the running time of a function ?

# %%
# find a way to evaluate the running time of foo2() function

def foo2():
    for n in range(1000):
        n**4

# %% [markdown]
# ### Question 10: How to design an Exception message within a function ?

# %%
# try to raise an exception message

def foo3(foo_input):
    if 0 <= foo_input <= 100:
        return f_input
    else: raise Exception(f"The number should be in [0, 100]. ({foo_input=})")
